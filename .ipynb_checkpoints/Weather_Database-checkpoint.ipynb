# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
n = 10 #number of coordinates to generate

lats = np.random.uniform(-90, 90, n)
lngs = np.random.uniform(-180, 180, n)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lats_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lats_lngs)
coordinates
# Out:
# [(-76.42499245143559, -64.2613519389647),
#  (-9.865015023343403, -140.00501944186004),
#  (-17.284613989957876, 158.0775218301722),
#  (-12.042579537130024, -93.10253970791094),
#  (30.066685706500408, -163.16740519606952),
#  (20.65351656768928, -48.678417541492905),
#  (-61.46191965477786, -4.596314011302809),
#  (11.864414845569357, 147.26470443773206),
#  (62.337565277037584, 63.11992989424604),
#  (72.29547898020479, 48.47918640076358)]

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities =[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city=citipy.nearest_city(coordinate[0], coordinate[1])

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count

print(len(cities))
# Out:
# 10

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import json
import json

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url="https://api.openweathermap.org/data/2.5/weather?&APPID="+weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
i=0
for city in cities:
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.city_name.replace(" ","+") + "," + city.country_code + '&units=imperial'
    print(city_url)
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city.city_name},{city.country_code}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
   
    city_weather = requests.get(city_url).json()
    # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description  

    if city_weather["cod"]==200:
        # success!
#         city_weather_formatted_str = json.dumps(city_weather, indent=4)
#         print(city_weather_formatted_str)

        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description       
        long=round(city_weather['coord']['lon'],2)
        lat=round(city_weather['coord']['lat'],2)
        max_temp=city_weather['main']['temp_max']
        humidity=city_weather['main']['humidity']
        cloudiness=city_weather['clouds']['all']
        wind_speed=city_weather['wind']['speed']
        country=city_weather['sys']['country']
        city_name=city_weather['name']
        description=city_weather["weather"][0]["description"]
        city_datum={'Lat':lat,'Lng':long,'Max Temp':max_temp,'Humidity':humidity,'Cloudiness':cloudiness,'Wind Speed':wind_speed,'City':city_name,'Country':country,'Current Description':description}
        print(city_datum)
        # Append the city information into the city_data list
        city_data.append(city_datum)
    else:
        print("HTML Error: "+city_weather["cod"]+" Message: "+city_weather["message"])
    i+=1
    

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# https://api.openweathermap.org/data/2.5/weather?&APPID=492a5a3e5474d1017570fc55a90cc59e&q=ushuaia,ar&units=imperial
# Processing Record 1 of Set 1 | ushuaia,ar
# {
#     "coord": {
#         "lon": -68.3,
#         "lat": -54.8
#     },
#     "weather": [
#         {
#             "id": 501,
#             "main": "Rain",
#             "description": "moderate rain",
#             "icon": "10d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 58.66,
#         "feels_like": 55.92,
#         "temp_min": 58.66,
#         "temp_max": 58.66,
#         "pressure": 990,
#         "humidity": 36
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 16.11,
#         "deg": 300,
#         "gust": 27.63
#     },
#     "rain": {
#         "1h": 1.82
#     },
#     "clouds": {
#         "all": 75
#     },
#     "dt": 1678394726,
#     "sys": {
#         "type": 1,
#         "id": 8303,
#         "country": "AR",
#         "sunrise": 1678356734,
#         "sunset": 1678403736
#     },
#     "timezone": -10800,
#     "id": 3833367,
#     "name": "Ushuaia",
#     "cod": 200
# }
# {'Lat': -54.8, 'Lng': -68.3, 'Max Temp': 58.66, 'Humidity': 36, 'Cloudiness': 75, 'Wind Speed': 16.11, 'City': 'Ushuaia', 'Country': 'AR', 'Current Description': 'moderate rain'}
# https://api.openweathermap.org/data/2.5/weather?&APPID=492a5a3e5474d1017570fc55a90cc59e&q=atuona,pf&units=imperial
# Processing Record 2 of Set 1 | atuona,pf
# {
#     "coord": {
#         "lon": -139.0333,
#         "lat": -9.8
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 79.5,
#         "feels_like": 79.5,
#         "temp_min": 79.5,
#         "temp_max": 79.5,
#         "pressure": 1013,
#         "humidity": 75,
#         "sea_level": 1013,
#         "grnd_level": 1005
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 6.51,
#         "deg": 58,
#         "gust": 6.53
#     },
#     "clouds": {
#         "all": 4
#     },
#     "dt": 1678394853,
#     "sys": {
#         "country": "PF",
#         "sunrise": 1678375219,
#         "sunset": 1678419196
#     },
#     "timezone": -34200,
#     "id": 4020109,
#     "name": "Atuona",
#     "cod": 200
# }
# {'Lat': -9.8, 'Lng': -139.03, 'Max Temp': 79.5, 'Humidity': 75, 'Cloudiness': 4, 'Wind Speed': 6.51, 'City': 'Atuona', 'Country': 'PF', 'Current Description': 'clear sky'}
# https://api.openweathermap.org/data/2.5/weather?&APPID=492a5a3e5474d1017570fc55a90cc59e&q=poum,nc&units=imperial
# Processing Record 3 of Set 1 | poum,nc
# {
#     "coord": {
#         "lon": 164.0167,
#         "lat": -20.2333
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 80.55,
#         "feels_like": 83.55,
#         "temp_min": 80.55,
#         "temp_max": 80.55,
#         "pressure": 1013,
#         "humidity": 68,
#         "sea_level": 1013,
#         "grnd_level": 1013
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 12.28,
#         "deg": 96,
#         "gust": 15.05
#     },
#     "clouds": {
#         "all": 19
#     },
#     "dt": 1678394854,
#     "sys": {
#         "country": "NC",
#         "sunrise": 1678388670,
#         "sunset": 1678433077
#     },
#     "timezone": 39600,
#     "id": 2138555,
#     "name": "Poum",
#     "cod": 200
# }
# {'Lat': -20.23, 'Lng': 164.02, 'Max Temp': 80.55, 'Humidity': 68, 'Cloudiness': 19, 'Wind Speed': 12.28, 'City': 'Poum', 'Country': 'NC', 'Current Description': 'few clouds'}
# https://api.openweathermap.org/data/2.5/weather?&APPID=492a5a3e5474d1017570fc55a90cc59e&q=puerto+ayora,ec&units=imperial
# Processing Record 4 of Set 1 | puerto ayora,ec
# {
#     "coord": {
#         "lon": -90.3518,
#         "lat": -0.7393
#     },
#     "weather": [
#         {
#             "id": 500,
#             "main": "Rain",
#             "description": "light rain",
#             "icon": "10d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 81.55,
#         "feels_like": 89.37,
#         "temp_min": 81.55,
#         "temp_max": 87.76,
#         "pressure": 1008,
#         "humidity": 87
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 13,
#         "deg": 236,
#         "gust": 21
#     },
#     "rain": {
#         "1h": 0.29
#     },
#     "clouds": {
#         "all": 98
#     },
#     "dt": 1678394854,
#     "sys": {
#         "type": 2,
#         "id": 2005652,
#         "country": "EC",
#         "sunrise": 1678363712,
#         "sunset": 1678407340
#     },
#     "timezone": -21600,
#     "id": 3652764,
#     "name": "Puerto Ayora",
#     "cod": 200
# }
# {'Lat': -0.74, 'Lng': -90.35, 'Max Temp': 87.76, 'Humidity': 87, 'Cloudiness': 98, 'Wind Speed': 13, 'City': 'Puerto Ayora', 'Country': 'EC', 'Current Description': 'light rain'}
# https://api.openweathermap.org/data/2.5/weather?&APPID=492a5a3e5474d1017570fc55a90cc59e&q=kapaa,us&units=imperial
# Processing Record 5 of Set 1 | kapaa,us
# {
#     "coord": {
#         "lon": -159.319,
#         "lat": 22.0752
#     },
#     "weather": [
#         {
#             "id": 500,
#             "main": "Rain",
#             "description": "light rain",
#             "icon": "10d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 75.49,
#         "feels_like": 74.98,
#         "temp_min": 75.11,
#         "temp_max": 76.19,
#         "pressure": 1014,
#         "humidity": 48
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.61,
#         "deg": 220
#     },
#     "clouds": {
#         "all": 20
#     },
#     "dt": 1678394855,
#     "sys": {
#         "type": 2,
#         "id": 2001562,
#         "country": "US",
#         "sunrise": 1678380693,
#         "sunset": 1678423458
#     },
#     "timezone": -36000,
#     "id": 5848280,
#     "name": "Kapaa",
#     "cod": 200
# }
# {'Lat': 22.08, 'Lng': -159.32, 'Max Temp': 76.19, 'Humidity': 48, 'Cloudiness': 20, 'Wind Speed': 4.61, 'City': 'Kapaa', 'Country': 'US', 'Current Description': 'light rain'}
# https://api.openweathermap.org/data/2.5/weather?&APPID=492a5a3e5474d1017570fc55a90cc59e&q=bathsheba,bb&units=imperial
# Processing Record 6 of Set 1 | bathsheba,bb
# {
#     "coord": {
#         "lon": -59.5167,
#         "lat": 13.2167
#     },
#     "weather": [
#         {
#             "id": 802,
#             "main": "Clouds",
#             "description": "scattered clouds",
#             "icon": "03d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 83.01,
#         "feels_like": 88.14,
#         "temp_min": 83.01,
#         "temp_max": 83.01,
#         "pressure": 1011,
#         "humidity": 69
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 8.05,
#         "deg": 140
#     },
#     "clouds": {
#         "all": 40
#     },
#     "dt": 1678394856,
#     "sys": {
#         "type": 1,
#         "id": 8772,
#         "country": "BB",
#         "sunrise": 1678356579,
#         "sunset": 1678399676
#     },
#     "timezone": -14400,
#     "id": 3374083,
#     "name": "Bathsheba",
#     "cod": 200
# }
# {'Lat': 13.22, 'Lng': -59.52, 'Max Temp': 83.01, 'Humidity': 69, 'Cloudiness': 40, 'Wind Speed': 8.05, 'City': 'Bathsheba', 'Country': 'BB', 'Current Description': 'scattered clouds'}
# https://api.openweathermap.org/data/2.5/weather?&APPID=492a5a3e5474d1017570fc55a90cc59e&q=cape+town,za&units=imperial
# Processing Record 7 of Set 1 | cape town,za
# {
#     "coord": {
#         "lon": 18.4232,
#         "lat": -33.9258
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 61.16,
#         "feels_like": 61.21,
#         "temp_min": 59.11,
#         "temp_max": 63.12,
#         "pressure": 1015,
#         "humidity": 90
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.61,
#         "deg": 260
#     },
#     "clouds": {
#         "all": 75
#     },
#     "dt": 1678394800,
#     "sys": {
#         "type": 2,
#         "id": 2073005,
#         "country": "ZA",
#         "sunrise": 1678336833,
#         "sunset": 1678382017
#     },
#     "timezone": 7200,
#     "id": 3369157,
#     "name": "Cape Town",
#     "cod": 200
# }
# {'Lat': -33.93, 'Lng': 18.42, 'Max Temp': 63.12, 'Humidity': 90, 'Cloudiness': 75, 'Wind Speed': 4.61, 'City': 'Cape Town', 'Country': 'ZA', 'Current Description': 'broken clouds'}
# https://api.openweathermap.org/data/2.5/weather?&APPID=492a5a3e5474d1017570fc55a90cc59e&q=airai,pw&units=imperial
# Processing Record 8 of Set 1 | airai,pw
# HTML Error: 404 Message: city not found
# https://api.openweathermap.org/data/2.5/weather?&APPID=492a5a3e5474d1017570fc55a90cc59e&q=agirish,ru&units=imperial
# Processing Record 9 of Set 1 | agirish,ru
# {
#     "coord": {
#         "lon": 63.0231,
#         "lat": 61.9247
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 27.05,
#         "feels_like": 16.84,
#         "temp_min": 27.05,
#         "temp_max": 27.05,
#         "pressure": 1000,
#         "humidity": 85,
#         "sea_level": 1000,
#         "grnd_level": 980
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 11.41,
#         "deg": 222,
#         "gust": 30.89
#     },
#     "clouds": {
#         "all": 67
#     },
#     "dt": 1678394858,
#     "sys": {
#         "country": "RU",
#         "sunrise": 1678415021,
#         "sunset": 1678455193
#     },
#     "timezone": 18000,
#     "id": 1512101,
#     "name": "Agirish",
#     "cod": 200
# }
# {'Lat': 61.92, 'Lng': 63.02, 'Max Temp': 27.05, 'Humidity': 85, 'Cloudiness': 67, 'Wind Speed': 11.41, 'City': 'Agirish', 'Country': 'RU', 'Current Description': 'broken clouds'}
# https://api.openweathermap.org/data/2.5/weather?&APPID=492a5a3e5474d1017570fc55a90cc59e&q=belushya+guba,ru&units=imperial
# Processing Record 10 of Set 1 | belushya guba,ru
# HTML Error: 404 Message: city not found
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 8

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#      Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed          City  \
# 0 -54.80  -68.30     58.66        36          75       16.11       Ushuaia
# 1  -9.80 -139.03     79.50        75           4        6.51        Atuona
# 2 -20.23  164.02     80.55        68          19       12.28          Poum
# 3  -0.74  -90.35     87.76        87          98       13.00  Puerto Ayora
# 4  22.08 -159.32     76.19        48          20        4.61         Kapaa
# 5  13.22  -59.52     83.01        69          40        8.05     Bathsheba
# 6 -33.93   18.42     63.12        90          75        4.61     Cape Town
# 7  61.92   63.02     27.05        85          67       11.41       Agirish
#
#   Country Current Description
# 0      AR       moderate rain
# 1      PF           clear sky
# 2      NC          few clouds
# 3      EC          light rain
# 4      US          light rain
# 5      BB    scattered clouds
# 6      ZA       broken clouds
# 7      RU       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed',
#        'City', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
col_names=["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df_final=city_data_df[col_names]

# Display sample data
city_data_df_final.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0       Ushuaia      AR -54.80  -68.30     58.66        36          75
# 1        Atuona      PF  -9.80 -139.03     79.50        75           4
# 2          Poum      NC -20.23  164.02     80.55        68          19
# 3  Puerto Ayora      EC  -0.74  -90.35     87.76        87          98
# 4         Kapaa      US  22.08 -159.32     76.19        48          20
# 5     Bathsheba      BB  13.22  -59.52     83.01        69          40
# 6     Cape Town      ZA -33.93   18.42     63.12        90          75
# 7       Agirish      RU  61.92   63.02     27.05        85          67
#
#    Wind Speed Current Description
# 0       16.11       moderate rain
# 1        6.51           clear sky
# 2       12.28          few clouds
# 3       13.00          light rain
# 4        4.61          light rain
# 5        8.05    scattered clouds
# 6        4.61       broken clouds
# 7       11.41       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df_final.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
filename='WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df_final.to_csv(filename)
